# %%
import re

# %%
from tika import parser
import re
for i in range(1,3894):
    i = 1
    page = 0
    raw = parser.from_file('C:/Users/691/kdigital/채권분석리포트/{}.pdf'.format(i))
    raw["content"]
#     print(raw['content'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-75c54425e834> in <module>
#       3     i = 1
#       4     page = 0
# ----> 5     raw = parser.from_file('C:/Users/691/kdigital/채권분석리포트/{}.pdf'.format(i))
#       6     raw["content"]
#       7 #     print(raw['content'])
#
# ~\.conda\envs\study\lib\site-packages\tika\parser.py in from_file(filename, serverEndpoint, service, xmlContent, headers, config_path, requestOptions)
#      38     '''
#      39     if not xmlContent:
# ---> 40         output = parse1(service, filename, serverEndpoint, headers=headers, config_path=config_path, requestOptions=requestOptions)
#      41     else:
#      42         output = parse1(service, filename, serverEndpoint, services={'meta': '/meta', 'text': '/tika', 'all': '/rmeta/xml'},
#
# ...

# %%
from tika import parser
raw = parser.from_file('C:/Users/691/kdigital/채권분석리포트/10.pdf')
raw['content']
# Out:
# 2021-01-07 11:10:44,778 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# ...

# %%
import fitz
import re
num=3301
content_list=[]
content_list_final=[]
while 3301<=num<=3894:
    filename='C:/Users/691/kdigital/채권분석리포트/{}.pdf'.format(num)
    doc=fitz.open(filename)
    page_count=doc.pageCount
    page=0
    while (page<page_count):
        p=doc.loadPage(page)
        text=p.getText()
        content_list.append(text.strip().replace('\n',''))
        page+=1
    print('다운 {}개'.format(num))
    num=num+1
    text_sum=' '.join(content_list)
    content_list_final.append(text_sum)
# Out:
# 다운 3301개
# 다운 3302개
# 다운 3303개
# 다운 3304개
# 다운 3305개
# 다운 3306개
# 다운 3307개
# 다운 3308개
# 다운 3309개
# 다운 3310개
# 다운 3311개
# 다운 3312개
# 다운 3313개
# 다운 3314개
# 다운 3315개
# 다운 3316개
# 다운 3317개
# 다운 3318개
# 다운 3319개
# 다운 3320개
# 다운 3321개
# 다운 3322개
# 다운 3323개
# 다운 3324개
# 다운 3325개
# 다운 3326개
# 다운 3327개
# 다운 3328개
# 다운 3329개
# 다운 3330개
# 다운 3331개
# 다운 3332개
# 다운 3333개
# 다운 3334개
# 다운 3335개
# 다운 3336개
# 다운 3337개
# 다운 3338개
# 다운 3339개
# 다운 3340개
# 다운 3341개
# 다운 3342개
# 다운 3343개
# 다운 3344개
# 다운 3345개
# 다운 3346개
# 다운 3347개
# 다운 3348개
# 다운 3349개
# 다운 3350개
# 다운 3351개
# 다운 3352개
# 다운 3353개
# 다운 3354개
# 다운 3355개
# 다운 3356개
# 다운 3357개
# 다운 3358개
# 다운 3359개
# 다운 3360개
# 다운 3361개
# 다운 3362개
# 다운 3363개
# 다운 3364개
# 다운 3365개
# 다운 3366개
# 다운 3367개
# 다운 3368개
# 다운 3369개
# 다운 3370개
# 다운 3371개
# 다운 3372개
# 다운 3373개
# 다운 3374개
# 다운 3375개
# 다운 3376개
# 다운 3377개
# 다운 3378개
# 다운 3379개
# 다운 3380개
# 다운 3381개
# 다운 3382개
# 다운 3383개
# 다운 3384개
# 다운 3385개
# 다운 3386개
# 다운 3387개
# 다운 3388개
# 다운 3389개
# 다운 3390개
# ...

# %%
import pandas as pd
re8_data = {"다운":content_list}
re8_data = pd.DataFrame(re8_data)
re8_data.to_csv('re8_data_save.csv', encoding='utf-8')

# %%
import pandas as pd
re2_data = {"다운":content_list}
re2_data = pd.DataFrame(re2_data)
re2_data.to_csv('re2_data_save.csv', encoding='utf-8')

# %%
import pandas as pd
re3_data = {"다운":content_list}
re3_data = pd.DataFrame(re3_data)
re3_data.to_csv('re3_data_save.csv', encoding='utf-8')

# %%
import pandas as pd
re4_data = {"다운":content_list}
re4_data = pd.DataFrame(re4_data)
re4_data.to_csv('re4_data_save.csv', encoding='utf-8')

# %%
import pandas as pd
import glob
import os

input_file = r'C:/Users/691/cdigital' # csv파일들이 있는 디렉토리 위치
output_file = r'C:/Users/691/cdigita/rseult.csv' # 병합하고 저장하려는 파일명

allFile_list = glob.glob(os.path.join(input_file, 're*')) # glob함수로 sales_로 시작하는 파일들을 모은다
print(allFile_list)
allData = [] # 읽어 들인 csv파일 내용을 저장할 빈 리스트를 하나 만든다
for file in allFile_list:
    df = pd.read_csv(file) # for구문으로 csv파일들을 읽어 들인다
    allData.append(df) # 빈 리스트에 읽어 들인 내용을 추가한다
# Out:
# []

# %%
import pandas as pd
import glob
import os
input_file = r'C:\Users\691\kdigital' # csv파일들이 있는 디렉토리 위치
output_file = r'C:\Users\691\kdigital\result.csv' # 병합하고 저장하려는 파일명
# output_file1 = r'C:C:\Users\691\kdigital\bonds_data2.csv'
allFile_list = glob.glob(os.path.join(input_file, 're*')) # glob함수로 sales_로 시작하는 파일들을 모은다
print(allFile_list)
allData = [] # 읽어 들인 csv파일 내용을 저장할 빈 리스트를 하나 만든다
for file in allFile_list:
    df = pd.read_csv(file) # for구문으로 csv파일들을 읽어 들인다
    allData.append(df) # 빈 리스트에 읽어 들인 내용을 추가한다
    dataCombine = pd.concat(allData, axis=0, ignore_index=True) # concat함수를 이용해서 리스트의 내용을 병합
# axis=0은 수직으로 병합함. axis=1은 수평. ignore_index=True는 인데스 값이 기존 순서를 무시하고 순서대로 정렬되도록 한다.
    dataCombine.to_csv(output_file, index=False) # to_csv함수로 저장한다. 인데스를 빼려면 False로 설정
# Out:
# ['C:\\Users\\691\\kdigital\\re1_data_save.csv', 'C:\\Users\\691\\kdigital\\re2_data_save.csv', 'C:\\Users\\691\\kdigital\\re3_data_save.csv', 'C:\\Users\\691\\kdigital\\re4_data_save.csv', 'C:\\Users\\691\\kdigital\\re5_data_save.csv', 'C:\\Users\\691\\kdigital\\re6_data_save.csv', 'C:\\Users\\691\\kdigital\\re7_data_save.csv', 'C:\\Users\\691\\kdigital\\re8_data_save.csv']

# %%
import pandas as pd
import glob
import os
input_file = r'C:\Users\691\kdigital\새 폴더' # csv파일들이 있는 디렉토리 위치
output_file = r'C:\Users\691\kdigital\새 폴더\bonds_data3.csv' # 병합하고 저장하려는 파일명
# output_file1 = r'C:C:\Users\691\kdigital\bonds_data2.csv'
allFile_list = glob.glob(os.path.join(input_file, 're*')) # glob함수로 sales_로 시작하는 파일들을 모은다
print(allFile_list)
allData = [] # 읽어 들인 csv파일 내용을 저장할 빈 리스트를 하나 만든다
for file in allFile_list:
    df = pd.read_csv(file) # for구문으로 csv파일들을 읽어 들인다
    allData.append(df) # 빈 리스트에 읽어 들인 내용을 추가한다
    dataCombine = pd.concat(allData, axis=0, ignore_index=True) # concat함수를 이용해서 리스트의 내용을 병합
# axis=0은 수직으로 병합함. axis=1은 수평. ignore_index=True는 인데스 값이 기존 순서를 무시하고 순서대로 정렬되도록 한다.
    dataCombine.to_csv(output_file, index=False) # to_csv함수로 저장한다. 인데스를 빼려면 False로 설정
# Out:
# ['C:\\Users\\691\\kdigital\\새 폴더\\re10_data_save.csv', 'C:\\Users\\691\\kdigital\\새 폴더\\re9_data_save.csv']

# %%
import pandas as pd
import numpy as np

bonds_data3 = pd.read_csv("bonds_data3.csv")
bonds_data3
# Out:
#        Unnamed: 0                      제목        날짜  \
# 0               0              원점회귀(原點回歸)  20.12.30
# 1               1        포트폴리오 다변화로 가는 여정  20.12.23
# 2               2           2021년 전망 업데이트  20.12.23
# 3               3      일드 픽업 이제는 장기물이 답이다  20.12.18
# 4               4  10년 발행 감소, 초장기 공급부담 완화  20.12.18
# ...           ...                     ...       ...
# 35249        2275                     NaN       NaN
# 35250        2276                     NaN       NaN
# 35251        2277                     NaN       NaN
# 35252        2278                     NaN       NaN
# 35253        2279                     NaN       NaN
#
#                                                       다운
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# ...

# %%
bonds_data2 = pd.read_csv("bonds_data2_save.csv")
bonds_data2
# Out:
#       Unnamed: 0      date                   title  \
# 0              0  20.12.30              원점회귀(原點回歸)
# 1              1  20.12.23        포트폴리오 다변화로 가는 여정
# 2              2  20.12.23           2021년 전망 업데이트
# 3              3  20.12.18      일드 픽업 이제는 장기물이 답이다
# 4              4  20.12.18  10년 발행 감소, 초장기 공급부담 완화
# ...          ...       ...                     ...
# 3868        3868  08.04.21           항상 열려는 있는 가능성
# 3869        3869  08.04.14           총재의 변신은 무죄다?!
# 3870        3870  08.04.07                  시간차 공격
# 3871        3871  08.04.07                 돌아온 박스권
# 3872        3872  08.04.01       대우증권 월간 채권투자 (4월)
#
#                                                 content
# 0     원점회귀(原點回歸) Issue Comment Credit   Credit 김상만, ...
# 1     8  글로벌 채권┃ 2020.12.222020.12.222020.12.222020....
# 2     2021년 전망 업데이트 Issue Comment Credit   Credit 김상...
# 3     그림 1. P/F 및 벤치마크 수익률 추이  주1: 매매수수료 및 이자소득세는 반영...
# 4     Compliance Notice 본 조사자료는 고객의 투자에 정보를 제공할 목적으로...
# ...

# %%
from ekonlpy.tag import Mecab
mecab = Mecab()
mecab.pos("bonds_data2_save.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-c53b44cc6bfc> in <module>
#       1 from ekonlpy.tag import Mecab
#       2 mecab = Mecab()
# ----> 3 mecab.pos(bonds_data2_save.csv)
#
# NameError: name 'bonds_data2_save' is not defined
