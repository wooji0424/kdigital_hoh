# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/sise/sise_quant.nhn"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tr_list = soup.select("table.type_2 tr")

for tr in tr_list:
    if tr.select("a.tltle"):
        td_list = tr.select("td")
        print(td_list[0].text, td_list[1].text, td_list[2].text)
# Out:
# 1 KODEX 200선물인버스2X 2,720
# 2 KODEX 레버리지 21,810
# 3 금호에이치티 2,860
# 4 서울식품 230
# 5 삼성전자 78,900
# 6 KODEX 코스닥150선물인버스 4,525
# 7 화인베스틸 2,860
# 8 KODEX 인버스 4,430
# 9 KODEX 코스닥150 레버리지 16,040
# 10 대덕전자 12,100
# 11 쎌마테라퓨틱스 9,020
# 12 이아이디 341
# 13 DB 781
# 14 LG전자 129,000
# 15 덕성 9,050
# 16 신한 레버리지 WTI원유 선물 ETN(H) 375
# 17 팬오션 4,885
# 18 LG전자우 63,000
# 19 까뮤이앤씨 3,095
# 20 아남전자 2,440
# 21 신성이엔지 3,210
# 22 메리츠증권 3,985
# 23 LG디스플레이 18,700
# 24 유나이티드제약 67,800
# 25 KODEX 200 38,020
# 26 삼성전자우 73,300
# 27 삼부토건 3,985
# 28 대한전선 1,330
# 29 TIGER 200선물인버스2X 2,815
# 30 DB하이텍 44,550
# 31 삼성중공업 6,870
# 32 삼성 레버리지 WTI원유 선물 ETN 435
# 33 후성 11,800
# 34 대영포장 1,705
# 35 명신산업 43,000
# 36 KODEX 코스닥 150 14,920
# 37 알루코 4,720
# 38 서연 10,800
# 39 현대약품 7,140
# 40 써니전자 4,735
# 41 인바이오젠 6,380
# 42 명문제약 7,040
# 43 한국전력 27,050
# 44 HMM 12,700
# 45 세원셀론텍 2,925
# 46 부산주공 677
# 47 큐로 633
# 48 TIGER 200선물레버리지 16,390
# 49 파미셀 16,700
# 50 서연이화 8,070
# 51 두산중공업 12,850
# 52 대우건설 4,635
# 53 한화생명 2,435
# 54 KEC 2,740
# ...

# %%
url = "https://finance.naver.com/sise/sise_quant.nhn"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
tr_list = soup.select("table.type_2 tr")

for tr in tr_list:
    if tr.select("a.tltle"):
        td_list = tr.select("td")
        if td_list[3].select("span.red02"):
            print(td_list[0].text, td_list[1].text, td_list[3].text.strip())
# Out:
# 2 KODEX 레버리지 355
# 3 금호에이치티 135
# 5 삼성전자 1,300
# 8 화인베스틸 395
# 10 KODEX 코스닥150 레버리지 275
# 11 대덕전자 700
# 12 쎌마테라퓨틱스 1,240
# 13 LG전자 15,000
# 14 DB 23
# 15 덕성 1,090
# 17 팬오션 180
# 18 LG전자우 11,200
# 19 메리츠증권 125
# 21 아남전자 5
# 23 LG디스플레이 650
# 25 KODEX 200 250
# 26 유나이티드제약 5,100
# 27 삼성전자우 200
# 30 DB하이텍 1,800
# 33 후성 250
# 34 명신산업 2,200
# 35 KODEX 코스닥 150 150
# 36 대영포장 40
# 37 큐로 5
# 38 삼성제약 230
# 39 알루코 150
# 40 인바이오젠 390
# 41 서연 920
# 45 써니전자 40
# 46 한국전력 150
# 49 세원셀론텍 5
# 50 TIGER 200선물레버리지 265
# 52 한화생명 5
# 53 대우건설 10
# 55 서연이화 420
# 57 계양전기 70
# 58 기업은행 10
# 60 신풍제약 4,500
# 61 SK하이닉스 500
# 62 셀트리온 6,000
# 63 형지엘리트 100
# 67 삼아알미늄 380
# 68 BNK금융지주 40
# 69 TCC스틸 140
# 71 SK증권 2
# 73 LG유플러스 50
# 77 미래아이앤지 2
# 80 신한지주 100
# 86 일진홀딩스 240
# 88 대창 20
# 90 삼성 인버스 2X WTI원유 선물 ETN 5
# 91 TIGER 200 240
# 93 그린케미칼 60
# 94 TIGER 200 IT 545
# 98 대원화성 75

# %%
import re

# %%
url = "https://search.musinsa.com/category/001?device=&d_cat_cd=001&brand=&rate=&page_kind=search&list_kind=small&sort=pop&sub_sort=&page={}&display_cnt=90&sale_goods=&ex_soldout=&color=&price1=&price2=&exclusive_yn=&size=&tags=&sale_campaign_yn=&timesale_yn=&q="

for i in range(1, 11):
    response = requests.get(url.format(i))
    soup = BeautifulSoup(response.text, 'html.parser')
    li_list = soup.select("#searchList li")
    for li in li_list:
        p_list = li.select("div.article_info  p")
        if p_list:
            print("브랜드 : ", p_list[0].text.strip())
            print("제품명 : ", re.sub(r"\[.*?\]", "", p_list[1].text.strip()).strip())
            print("가격 : ", p_list[2].text.strip().split()[-1])
            print()
# Out:
# 브랜드 :  커스텀어스
# 제품명 :  삼각 시보리 카라티셔츠 CXS20WKKTA77
# 가격 :  89,000원
#
# 브랜드 :  이에스엔
# 제품명 :  하프 폴라 니트 티셔츠
# 가격 :  36,800원
#
# 브랜드 :  그루브라임
# 제품명 :  NYC LOCATION HOODIE
# 가격 :  69,000원
#
# 브랜드 :  그루브라임
# 제품명 :  (기모) NYC LOCATION SWEAT SHIRTS
# 가격 :  49,000원
#
# 브랜드 :  무신사 스탠다드
# 제품명 :  베이식 긴팔 티셔츠
# 가격 :  13,900원
#
# 브랜드 :  수아레
# 제품명 :  3일 지연
#
#                                     1+1 하프 터틀넥 니트
# 가격 :  46,200원
#
# 브랜드 :  무신사 스탠다드
# 제품명 :  레이어드 크루 넥 반팔 티셔츠
# 가격 :  13,900원
#
# 브랜드 :  무신사 스탠다드
# 제품명 :  베이식 긴팔 티셔츠
# 가격 :  13,900원
#
# 브랜드 :  무신사 스탠다드
# 제품명 :  릴렉스 핏 크루 넥 반팔 티셔츠
# 가격 :  11,900원
#
# 브랜드 :  제멋
# 제품명 :  12/30 배송
#                                     로그 오버핏 기모 후드 그레이 YHHD2302
# 가격 :  27,400원
#
# 브랜드 :  커버낫
# 제품명 :  부클 쿠퍼 로고 크루넥 네이비
# 가격 :  48,300원
#
# 브랜드 :  이에스엔
# 제품명 :  하프 폴라 니트 티셔츠 블랙
# 가격 :  21,000원
#
# 브랜드 :  블론드나인
# 제품명 :  3일 지연
#
#                                     CREW NECK RIB KNIT SWEATER_BLACK
# 가격 :  26,900원
#
# 브랜드 :  예일
# 제품명 :  1/19 배송
# ...

# %%
# !pip install selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('/Users/ronen/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')

# %%
driver.find_elements_by_css_selector("body > div.wrap > div.container_main > ul:nth-child(2) > li:nth-child(1) > a.thumb_title > span.title")[0].text
# Out:
# '시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’'

# %%
driver.find_elements_by_css_selector('body > div.wrap > div.container_main > ul> li > a.thumb_title > span.title')[0].text
# Out:
# '시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’'

# %%
driver = webdriver.Chrome('/Users/ronen/Downloads/chromedriver')
driver.get("https://www.hackerrank.com/")
login_btn = driver.find_element_by_css_selector("#menu-item-2887 > a")
#login_btn = driver.find_elements_by_css_selector("#menu-item-2887 > a")[0]
login_btn.click()

# login_btn2 = driver.find_element_by_css_selector("#post-175 > div > div > div.fl-row.fl-row-full-width.fl-row-bg-none.fl-node-5bd106f71c93d.hr__header-form-section.hr__header-form-section--sign-up > div > div > div.fl-col-group.fl-node-5bd106f71c9ec.fl-col-group-custom-width > div.fl-col.fl-node-5bd106f71cd43 > div > div.fl-module.fl-module-button.fl-node-5bd106f71cbed.hr__builder-button.hr__builder-button--primary.hr__builder-button--primary--halo.hr__builder-button--lg > div > div > a")
login_btn2 = driver.find_element_by_css_selector(".fl-node-5bd106f71cd43 a.fl-button")
login_btn2.click()

input_id = driver.find_element_by_css_selector("#input-1")
input_pw = driver.find_element_by_css_selector("#input-2")

input_id.send_keys("chesed71@naver.com")
input_pw.send_keys("1qaz2wsX")

driver.find_element_by_css_selector("#tab-1-content-1 > div.login-form.auth-form.theme-m > form > div.form-item.clearfix > button").click()

# %%
import time

driver = webdriver.Chrome('/Users/ronen/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')
driver.implicitly_wait(5)
driver.find_element_by_css_selector("#more").click()
time.sleep(3)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
# !pip install selenium

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('/Users/ronen/Downloads/chromedriver')
driver.get('https://www.hackerrank.com/')
driver.find_element_by_css_selector("#menu-item-2887 > a").click()
driver.find_element_by_css_selector("#post-175 > div > div > div.fl-row.fl-row-full-width.fl-row-bg-none.fl-node-5bd106f71c93d.hr__header-form-section.hr__header-form-section--sign-up > div > div > div.fl-col-group.fl-node-5bd106f71c9ec.fl-col-group-custom-width > div.fl-col.fl-node-5bd106f71cd43 > div > div.fl-module.fl-module-button.fl-node-5bd106f71cbed.hr__builder-button.hr__builder-button--primary.hr__builder-button--primary--halo.hr__builder-button--lg > div > div > a").click()

input_id = driver.find_element_by_css_selector("#input-1")
input_pw = driver.find_element_by_css_selector("#input-2")

input_id.send_keys("chesed71@naver.com")
input_pw.send_keys("1qaz2wsX")

driver.find_elemnet_by_css_selector("#tab-1-content-1 > div.login-form.auth-form.theme-m > form > div.form-item.clearfix > button").click()

# %%
import requests

url = "http://openapi.epost.go.kr/postal/retrieveNewAdressAreaCdService/retrieveNewAdressAreaCdService/getNewAddressListAreaCd"
service_key = "VYtO7qnFRF%2FkznYj%2Bt62CTKqR5HcUAcu9Bt%2FUd15T1QjjjTzgjvc0mOPPNr9zVFvlwmyYe0Da0U2RilJmJjh0g%3D%3D"
service_key_decoded = requests.utils.unquote(service_key)
print(service_key_decoded)
# Out:
# VYtO7qnFRF/kznYj+t62CTKqR5HcUAcu9Bt/Ud15T1QjjjTzgjvc0mOPPNr9zVFvlwmyYe0Da0U2RilJmJjh0g==

# %%
req_parameter = {"ServiceKey": service_key_decoded, "searchSe":"road", "srchwrd": "반포대로 201"}
result = requests.get(url, params=req_parameter)
result.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><NewAddressListResponse><cmmMsgHeader><requestMsgId></requestMsgId><responseMsgId></responseMsgId><responseTime>20201228:145812456</responseTime><successYN>Y</successYN><returnCode>00</returnCode><errMsg></errMsg><totalCount>1</totalCount><countPerPage>10</countPerPage><totalPage>1</totalPage><currentPage></currentPage></cmmMsgHeader><newAddressListAreaCd><zipNo>06579</zipNo><lnmAdres>서울특별시 서초구 반포대로 201 (반포동, 국립중앙도서관)</lnmAdres><rnAdres>서울특별시 서초구 반포동 산60-1 국립중앙도서관</rnAdres></newAddressListAreaCd></NewAddressListResponse>'

# %%
url = "http://openapi.epost.go.kr/postal/retrieveNewAdressAreaCdService/retrieveNewAdressAreaCdService/getNewAddressListAreaCd?ServiceKey=VYtO7qnFRF%2FkznYj%2Bt62CTKqR5HcUAcu9Bt%2FUd15T1QjjjTzgjvc0mOPPNr9zVFvlwmyYe0Da0U2RilJmJjh0g%3D%3D&searchSe=road&srchwrd=강석로 152"
r = requests.get(url)
r.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><NewAddressListResponse><cmmMsgHeader><requestMsgId></requestMsgId><responseMsgId></responseMsgId><responseTime>20201228:151922467</responseTime><successYN>Y</successYN><returnCode>00</returnCode><errMsg></errMsg><totalCount>1</totalCount><countPerPage>10</countPerPage><totalPage>1</totalPage><currentPage></currentPage></cmmMsgHeader><newAddressListAreaCd><zipNo>10415</zipNo><lnmAdres>경기도 고양시 일산동구 강석로 152 (마두동, 강촌마을7단지아파트)</lnmAdres><rnAdres>경기도 고양시 일산동구 마두동 796 강촌마을7단지아파트</rnAdres></newAddressListAreaCd></NewAddressListResponse>'

# %%
# !pip install xmltodict

# %%
import xmltodict
dict_data = xmltodict.parse(result.text)
dict_data
# Out:
# OrderedDict([('NewAddressListResponse',
#               OrderedDict([('cmmMsgHeader',
#                             OrderedDict([('requestMsgId', None),
#                                          ('responseMsgId', None),
#                                          ('responseTime',
#                                           '20201228:145812456'),
#                                          ('successYN', 'Y'),
#                                          ('returnCode', '00'),
#                                          ('errMsg', None),
#                                          ('totalCount', '1'),
#                                          ('countPerPage', '10'),
#                                          ('totalPage', '1'),
#                                          ('currentPage', None)])),
#                            ('newAddressListAreaCd',
#                             OrderedDict([('zipNo', '06579'),
#                                          ('lnmAdres',
# ...

# %%
dict_data['NewAddressListResponse']['newAddressListAreaCd']['zipNo']
# Out:
# '06579'

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://finance.naver.com/sise/sise_quant.nhn"
response = requests.get(URL)
soup = BeautifulSoup(response.text,"html.parser")
print(soup.select_one("tbody"))
# Out:
# None

# %%
from selenium import webdriver

chromedriver = '/Users/ronen/Downloads/chromedriver'
options = webdriver.ChromeOptions()
options.add_argument('headless')

driver = webdriver.Chrome(chromedriver, chrome_options=options)
driver.get('https://finance.naver.com/sise/sise_quant.nhn')
print(driver.find_element_by_css_selector("tbody").text)
# Out:
# /Users/ronen/anaconda3/envs/mulcam/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys
# 거래량 매수호가 거래대금(백만) 시가총액(억) 영업이익(억) PER(배)
# 시가 매도호가 전일거래량 자산총계(억) 영업이익증가율 ROE(%)
# 고가 매수총잔량 외국인비율 부채총계(억) 당기순이익(억) ROA(%)
# 저가 매도총잔량 상장주식수(천주) 매출액(억) 주당순이익(원) PBR(배)
#       매출액증가율 보통주배당금(원) 유보율(%)

# %%
text = '<p class="price"><del>78,000원</del>				36,800원			</p>'
text2 = '<p class="price">				36,800원			</p>'

# %%
re.search(r'(?<=>)(<del>.*</del>)?(.*)(?=<)', text).group(2).strip()
# Out:
# '36,800원'

# %%
re.search(r'(?<=>)(<del>.*</del>)?(.*)(?=<)', text2).group(2).strip()
# Out:
# '36,800원'

# %%
from selenium import webdriver

import time

chromedriver = '/Users/ronen/Downloads/chromedriver'
options = webdriver.ChromeOptions()
options.add_argument('headless')

driver = webdriver.Chrome(chromedriver, chrome_options=options)

driver.get('https://www.jungle.co.kr/')
list_=driver.find_elements_by_css_selector('.thumb_title')

for i in list_:
    print(i.text)
driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
driver.find_elements_by_css_selector('#more')[0].click()
driver.implicitly_wait(2)

list_=driver.find_elements_by_css_selector('.thumb_title')
for i in list_:
    print(i.text)
# Out:
# /Users/ronen/anaconda3/envs/mulcam/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: use options instead of chrome_options
#   if __name__ == '__main__':
# 시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’
# '싱가포르 블루'에 담긴 싱가포르의 다양성과 아름다움
# LG하우시스가 발표한 2021/22 디자인 트렌드
# inner potential : 우리 모두에게 잠재된 능력의 발견
# 제 2회 팜(Farm)터지고 펀(Fun)한 농업농촌 영상 공모전(~ 11월 26일)
# 화성습지 23초 영화제 및 알락꼬리마도요 얼굴 찾기 공모전
# 인천 유나이티드의 마스코트 '유티 페이퍼토이’ 탄생
# 울산 울주군, ‘해뜨미’캐릭터 활동 본격화
# 신세계인터내셔날, MZ세대 맞춤형 뷰티 브랜드 ‘로이비’출시
# 하나카드, 신규 디지털 브랜드 ‘MULTI’ 출시
# 전남공예창작지원센터, 브랜드 로고 개발
# [미니인턴X팀와이퍼] 2주만에 '디자이너' 실무 역량 쌓고 채용연계까지? 미니인턴 지금 신
# 시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’
# '싱가포르 블루'에 담긴 싱가포르의 다양성과 아름다움
# LG하우시스가 발표한 2021/22 디자인 트렌드
# inner potential : 우리 모두에게 잠재된 능력의 발견
# 제 2회 팜(Farm)터지고 펀(Fun)한 농업농촌 영상 공모전(~ 11월 26일)
# 화성습지 23초 영화제 및 알락꼬리마도요 얼굴 찾기 공모전
# 인천 유나이티드의 마스코트 '유티 페이퍼토이’ 탄생
# 울산 울주군, ‘해뜨미’캐릭터 활동 본격화
# 신세계인터내셔날, MZ세대 맞춤형 뷰티 브랜드 ‘로이비’출시
# 하나카드, 신규 디지털 브랜드 ‘MULTI’ 출시
# 전남공예창작지원센터, 브랜드 로고 개발
# ...

# %%
from selenium import webdriver

import time

chromedriver = '/Users/ronen/Downloads/chromedriver'
options = webdriver.ChromeOptions()

driver = webdriver.Chrome(chromedriver)

driver.get('https://www.hanacard.co.kr/OPH30000000N.web?_frame=no&schID=pcd&mID=OPH30000000N')
time.sleep(5)
a_list=driver.find_elements_by_css_selector('div.log_box > div.btn a')
for a_tag in a_list:
    print(a_tag.text)
# Out:
# 이용대금명세서
# 카드이용내역
# 즉시결제
# 한도상향

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'
}

url = "https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0003064986"
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text,"html.parser")
print(soup.select_one("#cbox_module div.u_cbox_wrap"))
# Out:
# None

# %%
import time

chromedriver = '/Users/ronen/Downloads/chromedriver'
options = webdriver.ChromeOptions()

driver = webdriver.Chrome(chromedriver)

driver.get('https://news.naver.com/main/read.nhn?mode=LSD&mid=shm&sid1=102&oid=025&aid=0003064986')
time.sleep(5)
c_box=driver.find_element_by_css_selector('#cbox_module div.u_cbox_wrap')
c_box
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3bfefd91d0c0646b25d8a600191911df", element="55cae49d-12a3-44bf-99e9-28f01f541529")>
