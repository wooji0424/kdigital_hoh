# %%
import pandas as pd

# %%
x = [1,2,None,3,None,4,5]

# %%
x
# Out:
# [1, 2, None, 3, None, 4, 5]

# %%
x = pd.Series(x)
x
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    3.0
# 4    NaN
# 5    4.0
# 6    5.0
# dtype: float64

# %%
print(x.sum())
# Out:
# 15.0

# %%
print(x.isnull().sum())
# Out:
# 2

# %%
import numpy as np

# %%
x = [np.nan,1,2,3,4,5]

# %%
y = pd.Series([x[np.random.randint(0,6)]for i in range(20)])

# %%
y
# Out:
# 0     5.0
# 1     5.0
# 2     NaN
# 3     2.0
# 4     3.0
# 5     3.0
# 6     5.0
# 7     2.0
# 8     1.0
# 9     NaN
# 10    5.0
# 11    5.0
# 12    1.0
# 13    2.0
# 14    1.0
# 15    4.0
# 16    1.0
# 17    3.0
# 18    5.0
# 19    4.0
# dtype: float64

# %%
print(y.isnull().sum())
# Out:
# 2

# %%
print(y.dropna())
# Out:
# 0     5.0
# 1     5.0
# 3     2.0
# 4     3.0
# 5     3.0
# 6     5.0
# 7     2.0
# 8     1.0
# 10    5.0
# 11    5.0
# 12    1.0
# 13    2.0
# 14    1.0
# 15    4.0
# 16    1.0
# 17    3.0
# 18    5.0
# 19    4.0
# dtype: float64

# %%
print(y.mean())
# Out:
# 3.1666666666666665

# %%
y.fillna(y.mean())
# Out:
# 0     5.000000
# 1     5.000000
# 2     3.166667
# 3     2.000000
# 4     3.000000
# 5     3.000000
# 6     5.000000
# 7     2.000000
# 8     1.000000
# 9     3.166667
# 10    5.000000
# 11    5.000000
# 12    1.000000
# 13    2.000000
# 14    1.000000
# 15    4.000000
# 16    1.000000
# 17    3.000000
# 18    5.000000
# 19    4.000000
# dtype: float64

# %%
y.ffill()
# Out:
# 0     5.0
# 1     5.0
# 2     5.0
# 3     2.0
# 4     3.0
# 5     3.0
# 6     5.0
# 7     2.0
# 8     1.0
# 9     1.0
# 10    5.0
# 11    5.0
# 12    1.0
# 13    2.0
# 14    1.0
# 15    4.0
# 16    1.0
# 17    3.0
# 18    5.0
# 19    4.0
# dtype: float64

# %%
y.bfill()
# Out:
# 0     5.0
# 1     5.0
# 2     2.0
# 3     2.0
# 4     3.0
# 5     3.0
# 6     5.0
# 7     2.0
# 8     1.0
# 9     5.0
# 10    5.0
# 11    5.0
# 12    1.0
# 13    2.0
# 14    1.0
# 15    4.0
# 16    1.0
# 17    3.0
# 18    5.0
# 19    4.0
# dtype: float64

# %%
y[0] = np.NaN

# %%
y
# Out:
# 0     NaN
# 1     5.0
# 2     NaN
# 3     2.0
# 4     3.0
# 5     3.0
# 6     5.0
# 7     2.0
# 8     1.0
# 9     NaN
# 10    5.0
# 11    5.0
# 12    1.0
# 13    2.0
# 14    1.0
# 15    4.0
# 16    1.0
# 17    3.0
# 18    5.0
# 19    4.0
# dtype: float64

# %%
sales_data = {
 '연도':[2015, 2016, 2017, 2018, 2019, 2020],
 '판매량':[103, 70, 130, 160, 190, 230],
 '매출':[500000, 300000, 400000, 550000, 700000, 680000],
 '순이익':[370000, 190000, 300000, 480000, 600000, 590000]
}

# %%
sales_data
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
sales_data.head(2)
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000

# %%
sales_data["판매량"]
# Out:
# 0    103
# 1     70
# 2    130
# 3    160
# 4    190
# 5    230
# Name: 판매량, dtype: int64

# %%
sales_data.iloc[1]
# Out:
# 연도       2016
# 판매량        70
# 매출     300000
# 순이익    190000
# Name: 1, dtype: int64

# %%
pd.DataFrame(sales_data, columns=["판매량","매출","순이익"],index=sales_data["연도"])
# Out:
#       판매량  매출  순이익
# 연도
# 2015  NaN NaN  NaN
# 2016  NaN NaN  NaN
# 2017  NaN NaN  NaN
# 2018  NaN NaN  NaN
# 2019  NaN NaN  NaN
# 2020  NaN NaN  NaN

# %%
type(sales_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sales_data = {
 '연도':[2015, 2016, 2017, 2018, 2019, 2020],
 '판매량':[103, 70, 130, 160, 190, 230],
 '매출':[500000, 300000, 400000, 550000, 700000, 680000],
 '순이익':[370000, 190000, 300000, 480000, 600000, 590000]
}
sales_data
# Out:
# {'연도': [2015, 2016, 2017, 2018, 2019, 2020],
#  '판매량': [103, 70, 130, 160, 190, 230],
#  '매출': [500000, 300000, 400000, 550000, 700000, 680000],
#  '순이익': [370000, 190000, 300000, 480000, 600000, 590000]}

# %%
df = pd.DataFrame(sales_data)

# %%
df
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
df["판매량"]
# Out:
# 0    103
# 1     70
# 2    130
# 3    160
# 4    190
# 5    230
# Name: 판매량, dtype: int64

# %%
df.iloc[5]
# Out:
# 연도       2020
# 판매량       230
# 매출     680000
# 순이익    590000
# Name: 5, dtype: int64

# %%
pd.DataFrame(sales_data, columns=["판매량","매출","순이익"],index = sales_data["연도"])
# Out:
#       판매량      매출     순이익
# 2015  103  500000  370000
# 2016   70  300000  190000
# 2017  130  400000  300000
# 2018  160  550000  480000
# 2019  190  700000  600000
# 2020  230  680000  590000

# %%
type(sales_data)
# Out:
# dict

# %%
df = pd.read_csv("sales_data.csv", header = 0)
df
# Out:
#      연도  판매량      매출      순익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018   60  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
df = pd.read_csv("sales_data.csv", index_col='연도', header=0, sep=",")
df
# Out:
#       판매량      매출      순익
# 연도
# 2015  103  500000  370000
# 2016   70  300000  190000
# 2017  130  400000  300000
# 2018   60  550000  480000
# 2019  190  700000  600000
# 2020  230  680000  590000

# %%
df2 = pd.read_csv("sales_data.csv")
df2
# Out:
#      연도  판매량      매출      순익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018   60  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
sales_data.to_csv('sales_data2.csv', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-ddb0cd9d40b5> in <module>
# ----> 1 sales_data.to_csv('sales_data2.csv', encoding='utf-8')
#
# AttributeError: 'dict' object has no attribute 'to_csv'

# %%
sales_data = {
 '연도':[2015, 2016, 2017, 2018, 2019, 2020],
 '판매량':[103, 70, 130, 160, 190, 230],
 '매출':[500000, 300000, 400000, 550000, 700000, 680000],
'순이익':[370000, 190000, 300000, 480000, 600000, 590000]

}
sales_data
# Out:
# {'연도': [2015, 2016, 2017, 2018, 2019, 2020],
#  '판매량': [103, 70, 130, 160, 190, 230],
#  '매출': [500000, 300000, 400000, 550000, 700000, 680000],
#  '순이익': [370000, 190000, 300000, 480000, 600000, 590000]}

# %%
df = pd.DataFrame(sales_data)
df
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
df['순이익율'] = (df['순이익']/df['매출']) * 100

# %%
df
# Out:
#      연도  판매량      매출     순이익       순이익율
# 0  2015  103  500000  370000  74.000000
# 1  2016   70  300000  190000  63.333333
# 2  2017  130  400000  300000  75.000000
# 3  2018  160  550000  480000  87.272727
# 4  2019  190  700000  600000  85.714286
# 5  2020  230  680000  590000  86.764706

# %%
def check(n):
    if n > 80:
        return"높음"
    else:
        return"낮음"

# %%
df['순이익율_비교'] = df['순이익율'].apply(lambda n: "높음" if n > 80 else "낮음")

# %%
df
# Out:
#      연도  판매량      매출     순이익       순이익율 순이익율_비교
# 0  2015  103  500000  370000  74.000000      낮음
# 1  2016   70  300000  190000  63.333333      낮음
# 2  2017  130  400000  300000  75.000000      낮음
# 3  2018  160  550000  480000  87.272727      높음
# 4  2019  190  700000  600000  85.714286      높음
# 5  2020  230  680000  590000  86.764706      높음

# %%
for item in df.groupby("순이익율_비교"):
    print(type(item))
    print(item)
# Out:
# <class 'tuple'>
# ('낮음',      연도  판매량      매출     순이익       순이익율 순이익율_비교
# 0  2015  103  500000  370000  74.000000      낮음
# 1  2016   70  300000  190000  63.333333      낮음
# 2  2017  130  400000  300000  75.000000      낮음)
# <class 'tuple'>
# ('높음',      연도  판매량      매출     순이익       순이익율 순이익율_비교
# 3  2018  160  550000  480000  87.272727      높음
# 4  2019  190  700000  600000  85.714286      높음
# 5  2020  230  680000  590000  86.764706      높음)

# %%
del df['순이익율_비교']
df
# Out:
#      연도  판매량      매출     순이익       순이익률
# 0  2015  103  500000  370000  74.000000
# 1  2016   70  300000  190000  63.333333
# 2  2017  130  400000  300000  75.000000
# 3  2018  160  550000  480000  87.272727
# 4  2019  190  700000  600000  85.714286
# 5  2020  230  680000  590000  86.764706

# %%
df[df["매출"]> 500000]
# Out:
#      연도  판매량      매출     순이익       순이익률
# 3  2018  160  550000  480000  87.272727
# 4  2019  190  700000  600000  85.714286
# 5  2020  230  680000  590000  86.764706

# %%
df["테스트"] = np.where(df["판매량"] > 200 ,0, df["판매량"])

# %%
df
# Out:
#      연도  판매량      매출     순이익       순이익률  테스트
# 0  2015  103  500000  370000  74.000000  103
# 1  2016   70  300000  190000  63.333333   70
# 2  2017  130  400000  300000  75.000000  130
# 3  2018  160  550000  480000  87.272727  160
# 4  2019  190  700000  600000  85.714286  190
# 5  2020  230  680000  590000  86.764706    0

# %%
df["테스트2"] = df[df["판매량"]< 100]["판매량"]

# %%
df[df["판매량"]< 150]["판매량"] + 50
# Out:
# 0    153
# 1    120
# 2    180
# Name: 판매량, dtype: int64

# %%
df = pd.DataFrame(sales_data)
df
# Out:
#      연도  판매량      매출     순이익
# 0  2015  103  500000  370000
# 1  2016   70  300000  190000
# 2  2017  130  400000  300000
# 3  2018  160  550000  480000
# 4  2019  190  700000  600000
# 5  2020  230  680000  590000

# %%
df.loc[6] = [2021,720000,650000,360]
df
# Out:
#      연도     판매량      매출     순이익
# 0  2015     103  500000  370000
# 1  2016      70  300000  190000
# 2  2017     130  400000  300000
# 3  2018     160  550000  480000
# 4  2019     190  700000  600000
# 5  2020     230  680000  590000
# 6  2021  720000  650000     360

# %%
df.loc[7] = df.loc[5]+100

# %%
df
# Out:
#      연도     판매량      매출     순이익
# 0  2015     103  500000  370000
# 1  2016      70  300000  190000
# 2  2017     130  400000  300000
# 3  2018     160  550000  480000
# 4  2019     190  700000  600000
# 5  2120     330  680100  590100
# 6  2021  720000  650000     360
# 7  2220     430  680200  590200

# %%
df['순이익율'] = (df['순이익']/df['매출']) * 100

# %%
df
# Out:
#      연도     판매량      매출     순이익       순이익율
# 0  2015     103  500000  370000  74.000000
# 1  2016      70  300000  190000  63.333333
# 2  2017     130  400000  300000  75.000000
# 3  2018     160  550000  480000  87.272727
# 4  2019     190  700000  600000  85.714286
# 5  2120     330  680100  590100  86.766652
# 6  2021  720000  650000     360   0.055385
# 7  2220     430  680200  590200  86.768597

# %%
df.drop(["순이익율"],axis = 1, inplace=True)

# %%
df
# Out:
#      연도     판매량      매출     순이익
# 0  2015     103  500000  370000
# 1  2016      70  300000  190000
# 2  2017     130  400000  300000
# 3  2018     160  550000  480000
# 4  2019     190  700000  600000
# 5  2120     330  680100  590100
# 6  2021  720000  650000     360
# 7  2220     430  680200  590200

# %%
df.drop(df.columns[[0,2]],axis=1)
# Out:
#       판매량     순이익
# 0     103  370000
# 1      70  190000
# 2     130  300000
# 3     160  480000
# 4     190  600000
# 5     330  590100
# 6  720000     360
# 7     430  590200

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#      연도     판매량      매출     순이익
# 1  2016      70  300000  190000
# 2  2017     130  400000  300000
# 3  2018     160  550000  480000
# 4  2019     190  700000  600000
# 5  2120     330  680100  590100
# 6  2021  720000  650000     360
# 7  2220     430  680200  590200

# %%
df.drop([3,4,5],inplace =True)

# %%
df
# Out:
#      연도     판매량      매출     순이익
# 1  2016      70  300000  190000
# 2  2017     130  400000  300000
# 6  2021  720000  650000     360
# 7  2220     430  680200  590200

# %%
df = pd.DataFrame(np.random.randint(1, 100, size=(4, 4)), index=[['A','A','B','B'],['a','b','a','b']],

columns=[['가가','가가','나나','나나'],['가','나','가','나']])
df
# Out:
#      가가      나나
#       가   나   가   나
# A a   5  85   9   3
#   b  71  78  21  37
# B a  74  98  97  12
#   b  89  17  54  89

# %%
df.index
# Out:
# MultiIndex([('A', 'a'),
#             ('A', 'b'),
#             ('B', 'a'),
#             ('B', 'b')],
#            )

# %%
df.columns
# Out:
# MultiIndex([('가가', '가'),
#             ('가가', '나'),
#             ('나나', '가'),
#             ('나나', '나')],
#            )

# %%
# Out:
#   File "<ipython-input-173-a51b17031c58>", line 2
#     index=[['A창고','A창고','A창고','A창고','B창고','B창고','B창고','B창
#                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
df = pd.DataFrame(np.random.randint(1, 100, size=(8, 2)),
index=[['A창고','A창고','A창고','A창고','B창고','B창고','B창고','B창고'],
        ["사과","배","바나나","사과","사과","배","바나나","배"]],
columns=['판매','재고'])
df.index.names = ['창고명','상품명']

# %%
df
# Out:
#          판매  재고
# 창고명 상품명
# A창고 사과   47  90
#     배     3  26
#     바나나  41  63
#     사과   18  54
# B창고 사과    3  26
#     배    14  50
#     바나나  17  28
#     배     1  32

# %%
df.groupby("창고명").sum()
# Out:
#       판매   재고
# 창고명
# A창고  109  233
# B창고   35  136

# %%
df.groupby("상품명").sum()
# Out:
#      판매   재고
# 상품명
# 바나나  58   91
# 배    18  108
# 사과   68  170

# %%
df.groupby(["창고명","상품명"]).sum()
# Out:
#          판매   재고
# 창고명 상품명
# A창고 바나나  41   63
#     배     3   26
#     사과   65  144
# B창고 바나나  17   28
#     배    15   82
#     사과    3   26

# %%
df = pd.DataFrame(np.random.randint(1, 100, size=(8, 2)),
index=[['A창고','A창고','A창고','A창고','B창고','B창고','B창고','B창고'],
        ["사과","배","바나나","사과","사과","배","바나나","배"]],
columns=['판매','재고'])
df
# Out:
#          판매  재고
# A창고 사과   84  10
#     배    93  26
#     바나나  66  10
#     사과    8  93
# B창고 사과    4  73
#     배    28  27
#     바나나  93  27
#     배    82  20

# %%
df.sort_values(by="판매",ascending=True)
# Out:
#          판매  재고
# B창고 사과    4  73
# A창고 사과    8  93
# B창고 배    28  27
# A창고 바나나  66  10
# B창고 배    82  20
# A창고 사과   84  10
#     배    93  26
# B창고 바나나  93  27

# %%
df.sort_values(by=["판매", "재고"],ascending=[True, False])
# Out:
#          판매  재고
# B창고 사과    4  73
# A창고 사과    8  93
# B창고 배    28  27
# A창고 바나나  66  10
# B창고 배    82  20
# A창고 사과   84  10
# B창고 바나나  93  27
# A창고 배    93  26

# %%
df = pd.DataFrame(np.random.randint(1,100,size = (15,3)), 
index=[["1학년","1학년","1학년","1학년","1학년","2학년","2학년","2학년","2학년","2학년","3학년","3학년","3학년","3학년","3학년"],["1반","2반","3반","4반","5반","1반","2반","3반","4반","5반","1반","2반","3반","4반","5반"]], 
columns=["국어","영어","과학"])

# %%
df
# Out:
#         국어  영어  과학
# 1학년 1반  82  80  82
#     2반  40   8  42
#     3반  50  74  79
#     4반   9  28  95
#     5반  71  22  96
# 2학년 1반  84  59  69
#     2반  55  34  24
#     3반  11  72  46
#     4반   5  36  25
#     5반   2   2  69
# 3학년 1반  89  22  87
#     2반  31  70  74
#     3반   8   5  92
#     4반  75  29   7
#     5반  66  15  32

# %%
df["총점"] = (df["국어"]+df["영어"]+df["과학"])

# %%
df
# Out:
#         국어  영어  과학   총점
# 1학년 1반  82  80  82  244
#     2반  40   8  42   90
#     3반  50  74  79  203
#     4반   9  28  95  132
#     5반  71  22  96  189
# 2학년 1반  84  59  69  212
#     2반  55  34  24  113
#     3반  11  72  46  129
#     4반   5  36  25   66
#     5반   2   2  69   73
# 3학년 1반  89  22  87  198
#     2반  31  70  74  175
#     3반   8   5  92  105
#     4반  75  29   7  111
#     5반  66  15  32  113

# %%
df["평균"] = ((df["국어"]+df["영어"]+df["과학"])/3)

# %%
df
# Out:
#         국어  영어  과학   총점         평균
# 1학년 1반  82  80  82  244  81.333333
#     2반  40   8  42   90  30.000000
#     3반  50  74  79  203  67.666667
#     4반   9  28  95  132  44.000000
#     5반  71  22  96  189  63.000000
# 2학년 1반  84  59  69  212  70.666667
#     2반  55  34  24  113  37.666667
#     3반  11  72  46  129  43.000000
#     4반   5  36  25   66  22.000000
#     5반   2   2  69   73  24.333333
# 3학년 1반  89  22  87  198  66.000000
#     2반  31  70  74  175  58.333333
#     3반   8   5  92  105  35.000000
#     4반  75  29   7  111  37.000000
#     5반  66  15  32  113  37.666667

# %%
df.index.names = ["학년","반"]

# %%
df
# Out:
#         국어  영어  과학   총점         평균
# 학년  반
# 1학년 1반  82  80  82  244  81.333333
#     2반  40   8  42   90  30.000000
#     3반  50  74  79  203  67.666667
#     4반   9  28  95  132  44.000000
#     5반  71  22  96  189  63.000000
# 2학년 1반  84  59  69  212  70.666667
#     2반  55  34  24  113  37.666667
#     3반  11  72  46  129  43.000000
#     4반   5  36  25   66  22.000000
#     5반   2   2  69   73  24.333333
# 3학년 1반  89  22  87  198  66.000000
#     2반  31  70  74  175  58.333333
#     3반   8   5  92  105  35.000000
#     4반  75  29   7  111  37.000000
#     5반  66  15  32  113  37.666667

# %%
df.groupby("학년").sum()
# Out:
#       국어   영어   과학   총점          평균
# 학년
# 1학년  252  212  394  858  286.000000
# 2학년  157  203  233  593  197.666667
# 3학년  269  141  292  702  234.000000

# %%
df = pd.DataFrame(np.random.randint(1,100,size = (15,3)), 
index = [["1학년" for i in range(5)], + ["2학년" for i in range(5)], + ["3학년" for i in range(5)]],
        ["{}반".format(i) for i in range(1,6)]+["{}반".format(i) for i in range(1,6)]+["{}반".format(i) for i in range(1,6)],
columns = ["국어","영어","과학"])
# Out:
#   File "<ipython-input-260-f7f352574772>", line 3
#     ["{}반".format(i) for i in range(1,6)]+["{}반".format(i) for i in range(1,6)]+["{}반".format(i) for i in range(1,6)],
#     ^
# SyntaxError: positional argument follows keyword argument

# %%
titanic = pd.read_csv("train.csv")

# %%
titanic # 결측치 처리(age - 평균값적용, Cabin - N으로, Embarked- N)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
pd.DataFrame(titanic, columns=["Age"])
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
print(titanic.isnull())
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
titanic['Age'].fillna(titanic['Age'].mean(), inplace = True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500   NaN        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500   NaN        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000   NaN        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500   NaN        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic['Cabin'].fillna("N", inplace = True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500     N        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250     N        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500     N        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000     N        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500     N        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500     N        Q
#
# [891 rows x 12 columns]

# %%
titanic['Embarked'].fillna("N",inplace =True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 0        1      0         A/5 21171   7.2500     N        S
# 1        1      0          PC 17599  71.2833   C85        C
# 2        0      0  STON/O2. 3101282   7.9250     N        S
# 3        1      0            113803  53.1000  C123        S
# 4        0      0            373450   8.0500     N        S
# ..     ...    ...               ...      ...   ...      ...
# 886      0      0            211536  13.0000     N        S
# 887      0      0            112053  30.0000   B42        S
# 888      1      2        W./C. 6607  23.4500     N        S
# 889      0      0            111369  30.0000  C148        C
# 890      0      0            370376   7.7500     N        Q
#
# [891 rows x 12 columns]

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
titanic.groupby(['Sex','Survived']).sum()
# Out:
#                  PassengerId  Pclass           Age  SibSp  Parch        Fare
# Sex    Survived
# female 0               35223     231   2107.885000     98     84   1864.9752
#        1              100120     447   6752.168235    120    120  12101.6876
# male   0              210189    1159  14590.004706    206     97  10277.7447
#        1               51854     220   3011.855882     42     39   4449.5418

# %%
titanic.groupby("Pclass").sum()
# Out:
#         PassengerId  Survived           Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136   8002.393529     90     77  18177.4125
# 2             82056        87   5495.520294     74     70   3801.8417
# 3            215625       119  12964.000000    302    193   6714.6951

# %%
titanic["Sex"].head()
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
titanic.groupby("Sex")["Survived"].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
titanic.groupby("Sex")["Survived"].count()
# Out:
# Sex
# female    314
# male      577
# Name: Survived, dtype: int64

# %%
titanic.groupby(["Sex","Survived"])["Survived"].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
titanic.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
titanic["Age_Range"] = titanic["Age"].apply(lambda x: "유아" if x > 10 else "10대" if x > 20 else "20대" if x > 30 else "30")
# Out:
#   File "<ipython-input-406-a63428e73aaa>", line 1
#     titanic["Age_Range"] = titanic["Age"].apply(lambda x: "유아" if x > 10 else "10대" if x > 20 else "20대" if x > 30 else "30대" if x > 40 else "40대" if x > 50 else "50대" if x > 60 else "60대" else "노인")
#                                                                                                                                                                                              ^
# SyntaxError: invalid syntax

# %%
titanic["Age_Range"] = titanic["Age"].apply(lambda x: "유아" if x > 10 else "10대" if x > 20 else "20대" if x > 30 else "30대" if x > 40 else "40대" if x > 50 else "50대" if x > 60 else "60대" else "노인")

# %%
titanic["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
def changeAge(n):
    if n < 10:
        return "유아"
    else n < 20:
        return "10대"
# Out:
#   File "<ipython-input-386-3e40d0418206>", line 4
#     else n < 20:
#          ^
# SyntaxError: invalid syntax

# %%
pd.date_range(start="2019-01-10", end = "2019-01-17")
# Out:
# DatetimeIndex(['2019-01-10', '2019-01-11', '2019-01-12', '2019-01-13',
#                '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17'],
#               dtype='datetime64[ns]', freq='D')

# %%
table_date1 = {
    "A":[1,2,3,4,5],
    "B":[10,20,30,40,50],
    "C":[100,200,300,400,500]
}

# %%
table_date1
# Out:
# {'A': [1, 2, 3, 4, 5],
#  'B': [10, 20, 30, 40, 50],
#  'C': [100, 200, 300, 400, 500]}
